# %%
#MINOR PROJECT 1
#Take Any dataset of your choice and perfrom  EXPLORATORY DATA ANALYSIS and make sure you find out
#Atleast 15 different FACTS/CONCLUSION

# %%
#Dataset - 'https://www.kaggle.com/datasets/arnavsmayan/netflix-userbase-dataset'

# %%
#1.Taking the dataset and creating dataframe
import pandas as priti
Data = priti.read_csv('/content/Netflix Userbase.csv')
Data
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0           1             Basic               10  15-01-22          10-06-23
# 1           2           Premium               15  05-09-21          22-06-23
# 2           3          Standard               12  28-02-23          27-06-23
# 3           4          Standard               12  10-07-22          26-06-23
# 4           5             Basic               10  01-05-23          28-06-23
# ...       ...               ...              ...       ...               ...
# 2495     2496           Premium               14  25-07-22          12-07-23
# 2496     2497             Basic               15  04-08-22          14-07-23
# 2497     2498          Standard               12  09-08-22          15-07-23
# 2498     2499          Standard               13  12-08-22          12-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
# ...

# %%
Data.size
# Out:
# 25000

# %%
Data.info
# Out:
# <bound method DataFrame.info of       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0           1             Basic               10  15-01-22          10-06-23
# 1           2           Premium               15  05-09-21          22-06-23
# 2           3          Standard               12  28-02-23          27-06-23
# 3           4          Standard               12  10-07-22          26-06-23
# 4           5             Basic               10  01-05-23          28-06-23
# ...       ...               ...              ...       ...               ...
# 2495     2496           Premium               14  25-07-22          12-07-23
# 2496     2497             Basic               15  04-08-22          14-07-23
# 2497     2498          Standard               12  09-08-22          15-07-23
# 2498     2499          Standard               13  12-08-22          12-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
# ...

# %%
Data.shape
# Out:
# (2500, 10)

# %%
Data.Gender
# Out:
# 0         Male
# 1       Female
# 2         Male
# 3       Female
# 4         Male
#          ...
# 2495    Female
# 2496    Female
# 2497      Male
# 2498    Female
# 2499    Female
# Name: Gender, Length: 2500, dtype: object

# %%
#Let us check the null/missing valus in detail
Data.isnull().sum()
# Out:
# User ID              0
# Subscription Type    0
# Monthly Revenue      0
# Join Date            0
# Last Payment Date    0
# Country              0
# Age                  0
# Gender               0
# Device               0
# Plan Duration        0
# dtype: int64

# %%
#I want to know the count of unique of unique elements in the Name colume
Data['Subscription Type'].nunique()
# Out:
# 3

# %%
#I want the unique elements from the name colume
Data['Subscription Type'].unique()
# Out:
# array(['Basic', 'Premium', 'Standard'], dtype=object)

# %%
#VISUALISATION
import seaborn as sns
sns.countplot(x = 'Subscription Type',data = Data)
# Out:
# <Axes: xlabel='Subscription Type', ylabel='count'>

# %%
# I want to know about how many male and females have taken the Subscription
Data.groupby('Gender').size()
# Out:
# Gender
# Female    1257
# Male      1243
# dtype: int64

# %%
#Graphical representation
sns.countplot(x = 'Gender',data = Data)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
#I want to know how many males and females of same and differenet age group have taken the Subscription
Data.groupby(['Gender','Age']).size()
# Out:
# Gender  Age
# Female  26      1
#         27     38
#         28     57
#         29     47
#         30     57
#         31     56
#         32     50
#         33     42
#         34     51
#         35     49
#         36     48
#         37     51
#         38     33
#         39     57
#         40     54
#         41     56
#         42     59
#         43     44
#         44     51
#         45     46
#         46     53
#         47     59
#         48     57
#         49     50
#         50     41
#         51     50
# Male    27     49
#         28     58
#         29     57
#         30     59
#         31     59
#         32     42
#         33     51
#         34     37
#         35     56
#         36     51
#         37     56
#         38     56
#         39     59
#         40     49
#         41     58
#         42     43
#         43     50
#         44     35
#         45     43
#         46     46
#         47     52
#         48     44
#         49     47
# ...

# %%
#Let us now consider the Age column and create 4 age groups
import numpy as np
young = np.sum((Data['Age']>=0)&(Data['Age']<20))
adult =np.sum((Data['Age']>=20)&(Data['Age']<40))
midage =np.sum((Data['Age']>40)&(Data['Age']<60))
old =np.sum((Data['Age']>=60))
print(young)
print(adult)
print(midage)
print(old)
# Out:
# 0
# 1327
# 1070
# 0

# %%
1327+1070
# Out:
# 2397

# %%
#Full details of age between 25 to 35
Data[Data['Age'].between(25,35)]
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0           1             Basic               10  15-01-22          10-06-23
# 1           2           Premium               15  05-09-21          22-06-23
# 4           5             Basic               10  01-05-23          28-06-23
# 5           6           Premium               15  18-03-22          27-06-23
# 10         11             Basic               10  16-05-22          22-06-23
# ...       ...               ...              ...       ...               ...
# 2491     2492             Basic               14  19-07-22          12-07-23
# 2492     2493          Standard               11  20-07-22          11-07-23
# 2495     2496           Premium               14  25-07-22          12-07-23
# 2496     2497             Basic               15  04-08-22          14-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
# ...

# %%
#I want to know the eldest person age who have taken the Subscription
np.max(Data['Age'])
# Out:
# 51

# %%
#I want to know the youngest person age who have taken the Subscription
np.min(Data['Age'])
# Out:
# 26

# %%
#I want to know the full details of the eldest person.
Data[Data['Age']==51]
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 3           4          Standard               12  10-07-22          26-06-23
# 75         76             Basic               13  29-12-21          26-06-23
# 121       122             Basic               11  03-05-22          28-06-23
# 158       159          Standard               10  21-12-22          26-06-23
# 215       216           Premium               14  08-10-22          24-06-23
# ...       ...               ...              ...       ...               ...
# 2377     2378          Standard               11  22-10-22          11-07-23
# 2392     2393          Standard               12  07-11-22          11-07-23
# 2425     2426           Premium               15  23-07-22          12-07-23
# 2448     2449           Premium               10  27-10-22          09-07-23
# 2478     2479          Standard               11  16-08-22          11-07-23
#
# ...

# %%
#i want to know how many basic,Premium,Standard have Device Laptop,SmartTV,Smartphone,Tablet.
Data.groupby(['Subscription Type','Device']).size()
# Out:
# Subscription Type  Device
# Basic              Laptop        259
#                    Smart TV      238
#                    Smartphone    251
#                    Tablet        251
# Premium            Laptop        192
#                    Smart TV      188
#                    Smartphone    171
#                    Tablet        182
# Standard           Laptop        185
#                    Smart TV      184
#                    Smartphone    199
#                    Tablet        200
# dtype: int64

# %%
Basic_D_Laptop = np.sum((Data['Device']=='Laptop')&(Data['Subscription Type']=='Basic'))
print(Basic_D_Laptop)
# Out:
# 259

# %%
Premium_D_Laptop = np.sum((Data['Device']=='Laptop')&(Data['Subscription Type']=='Premium'))
print(Premium_D_Laptop)
# Out:
# 192

# %%
Standard_D_Laptop = np.sum((Data['Device']=='Laptop')&(Data['Subscription Type']=='Standard'))
print(Standard_D_Laptop)
# Out:
# 185

# %%
#Graphical representation
sns.countplot(x = 'Device',data = Data)
# Out:
# <Axes: xlabel='Device', ylabel='count'>

# %%
#I want full details of country having "United States"
Data[Data['Country']=='United States']
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0           1             Basic               10  15-01-22          10-06-23
# 10         11             Basic               10  16-05-22          22-06-23
# 20         21           Premium               15  10-06-23          22-06-23
# 30         31           Premium               15  03-02-23          22-06-23
# 40         41           Premium               15  20-01-23          22-06-23
# ...       ...               ...              ...       ...               ...
# 2482     2483             Basic               15  28-07-22          11-07-23
# 2484     2485           Premium               14  25-07-22          12-07-23
# 2485     2486             Basic               10  25-07-22          14-07-23
# 2497     2498          Standard               12  09-08-22          15-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
# ...

# %%
#I want full details of country having "Canada"
Data[Data['Country']=='Canada']
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 1           2           Premium               15  05-09-21          22-06-23
# 11         12           Premium               15  23-03-23          28-06-23
# 21         22             Basic               10  22-07-22          28-06-23
# 31         32             Basic               10  07-07-22          28-06-23
# 41         42             Basic               10  15-06-22          28-06-23
# ...       ...               ...              ...       ...               ...
# 2468     2469           Premium               12  24-10-22          11-07-23
# 2471     2472             Basic               14  29-09-22          14-07-23
# 2483     2484          Standard               11  29-07-22          13-07-23
# 2486     2487           Premium               11  25-07-22          12-07-23
# 2498     2499          Standard               13  12-08-22          12-07-23
#
# ...

# %%
#I want to know from how many country, how many Subscription are there.
Data['Country'].value_counts()
# Out:
# United States     451
# Spain             451
# Canada            317
# United Kingdom    183
# Australia         183
# Germany           183
# France            183
# Brazil            183
# Mexico            183
# Italy             183
# Name: Country, dtype: int64

# %%
#I want to know how many Australia,Brazil,Canada,France,Germany,Italy,Mexico,Spain,United Kingdom,United States have Subscription Type as basic,Premium,Standard
Data.groupby(['Country','Subscription Type']).size()
# Out:
# Country         Subscription Type
# Australia       Basic                 31
#                 Premium              101
#                 Standard              51
# Brazil          Basic                146
#                 Premium               33
#                 Standard               4
# Canada          Basic                145
#                 Premium               88
#                 Standard              84
# France          Basic                 36
#                 Premium              147
# Germany         Basic                149
#                 Premium                3
#                 Standard              31
# Italy           Basic                176
#                 Premium                4
#                 Standard               3
# Mexico          Basic                  4
#                 Standard             179
# Spain           Basic                110
#                 Premium              212
#                 Standard             129
# ...

# %%
Australia_S_Basic = np.sum((Data['Subscription Type']=='Basic')&(Data['Country']=='Australia'))
print(Australia_S_Basic)
# Out:
# 31

# %%
Spain_S_Basic = np.sum((Data['Subscription Type']=='Basic')&(Data['Country']=='Spain'))
print(Spain_S_Basic)
# Out:
# 110

# %%
Germany_S_Basic = np.sum((Data['Subscription Type']=='Basic')&(Data['Country']=='Germany'))
print(Germany_S_Basic)
# Out:
# 149

# %%
#Graphical representation
sns.countplot(x = 'Country',data = Data)
# Out:
# <Axes: xlabel='Country', ylabel='count'>
